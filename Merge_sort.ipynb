# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Построим графики зависимости T(P), S(P), E(P) при числе потоков N = 100000 и максимальном размере чанка m = 1000.

# %%
P = np.array([1, 2, 4, 8, 16])
T = np.array([0.04688, 0.03906, 0.03258, 0.02944, 0.03025])
S = T[0] / T 
E = S / P
Qsort_t = 0.04818

# %%
plt.figure(figsize=(15, 9))
plt.xlabel('P')
plt.ylabel('T')
plt.title('T(P)')
plt.plot(P, T, '.-', label='Merge sort')
plt.axhline(Qsort_t, label='Qsort', color = 'red')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.xlabel('P')
plt.ylabel('S')
plt.title('S(P)')
plt.plot(P, S, '.-')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.xlabel('P')
plt.ylabel('E')
plt.title('E(P)')
plt.plot(P, E, '.-')
plt.grid()
plt.show()
