# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Составим графики зависимости T(N), S(N), E(N) при фиксированном P = 16.

# %%
N = np.arange(10000, 110000, 10000)
T_1 = np.array([1.89844, 3.83594, 5.75195, 7.61133, 9.59570, 11.65039, 13.55469, 15.36328, 17.30859, 19.33789])
T_16 = np.array([1.36328, 2.65430, 3.77344, 5.40625, 6.61328, 7.94727, 8.90430, 10.79102, 11.12109, 13.42969])
S = T_1 / T_16
E = S / 16

# %%
plt.figure(figsize=(15, 9))
plt.axis([0, 110000, 0, 21])
plt.xlabel('N')
plt.ylabel('T')
plt.title('P = 2')
plt.grid()
plt.plot(N, T_2, '.-')
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.xlabel('N')
plt.ylabel('S')
plt.title('P = 2')
plt.grid()
plt.plot(N, S, '.-')
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.xlabel('N')
plt.ylabel('E')
plt.title('P = 2')
plt.grid()
plt.plot(N, E, '.-')
plt.show()

# %%
P = np.array([1, 2, 4, 8, 16])
T = np.array([1.96484, 2.02148, 1.97852, 2.01758, 1.30273])
S = np.full(T.size, T[0]) / T
E = S / P

# %%
plt.figure(figsize=(15, 9))
plt.xlabel('P')
plt.ylabel('T')
plt.grid()
plt.plot(P, T, '.-')
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.xlabel('P')
plt.ylabel('S')
plt.grid()
plt.plot(P, S, '.-')
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.xlabel('P')
plt.ylabel('E')
plt.grid()
plt.plot(P, E, '.-')
plt.show()
